# %% [markdown]
# This time we will be implementing an RNN model.
#
# Time series forcasting is an important topic in Machine Learning.\
# In this, we will are given the data for sunspots from jan 1749 to dec 1983.\
# we will be dividing this data in to two parts, one for training our model and second for testing our model.\
# In time series forcasting, we will have to take continuous data and not randomized data, because we have to predict on the basis of given past data.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# We will have to take the data from the url given.
#
# You have to implement the get_train_test function and return train_data and test_data, scaled in the range [0,1]
#
# To scale the data, read on MinMaxScalar class in sklearn.preprocessing
#
# Testing data should be the first 80 percent values and rest should be testing data. Also, convert the index of the data to datetime

# %%
from sklearn.preprocessing import MinMaxScaler
def get_train_test(url):
    df = pd.read_csv(url)
    df['Date'] = pd.to_datetime(df['Month'])
    df.set_index('Date', inplace=True)
    df = df['Sunspots'].values.reshape(-1,1)
    index = int(len(df)*0.8)
    train_data = df[:index]
    test_data = df[index:]
    scaler = MinMaxScaler()
    train_data = scaler.fit_transform(train_data)
    test_data = scaler.transform(test_data)
    return train_data, test_data

# %% [markdown]
# Now we will take the data from your implemented function :)

# %%
sunspots_url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/monthly-sunspots.csv'
train_data, test_data = get_train_test(sunspots_url)

X_train = train_data[:-1]
y_train = train_data[1:]

X_test = test_data[:-1]
y_test = test_data[1:]

# %% [markdown]
# Now let's make the model for our computations.
#
# The model will consist of a layer of RNN of 64 nodes followed by a layer of Feed Forward Neural Network of one output node.
#
# For compiling the node, we will use mean squared error as loss and mean absolute error as metric. We will not use accuracy as the metric. Think on why :)

# %%
# make the model .... all the best
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN

def create_sequence(X, y, time_steps=1):
    X, y = [], []
    for i in range(len(X) - time_steps):
        X.append(X[i:i+time_steps])
        y.append(y[i+time_steps])
    return np.array(X), np.array(y)

def model(input_shape):
    model = Sequential()
    model.add(SimpleRNN(64, activation='relu', input_shape=input_shape))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])
    return model

# train the model on the X_train dataset
X_train_reshape = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test_reshape = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])
model = model(X_train_reshape.shape[1:])
model.fit(X_train_reshape, y_train, epochs=100, batch_size=32)

# predict the values for training and testing data
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0344 - mean_absolute_error: 0.1287
# Epoch 2/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0083 - mean_absolute_error: 0.0694
# Epoch 3/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0052 - mean_absolute_error: 0.0540
# Epoch 4/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0047 - mean_absolute_error: 0.0502
# Epoch 5/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0047 - mean_absolute_error: 0.0489
# Epoch 6/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mean_absolute_error: 0.0465
# Epoch 7/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0045 - mean_absolute_error: 0.0471
# Epoch 8/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0468
# Epoch 9/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mean_absolute_error: 0.0462
# Epoch 10/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0042 - mean_absolute_error: 0.0460
# Epoch 11/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0045 - mean_absolute_error: 0.0465
# Epoch 12/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - mean_absolute_error: 0.0478
# Epoch 13/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0042 - mean_absolute_error: 0.0460
# Epoch 14/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0046 - mean_absolute_error: 0.0479
# Epoch 15/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mean_absolute_error: 0.0472
# Epoch 16/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0493
# Epoch 17/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0047 - mean_absolute_error: 0.0484
# Epoch 18/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mean_absolute_error: 0.0469
# Epoch 19/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0043 - mean_absolute_error: 0.0473
# Epoch 20/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0491
# Epoch 21/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0042 - mean_absolute_error: 0.0458
# Epoch 22/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mean_absolute_error: 0.0481
# Epoch 23/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0481
# Epoch 24/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mean_absolute_error: 0.0476
# Epoch 25/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mean_absolute_error: 0.0468
# Epoch 26/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0042 - mean_absolute_error: 0.0461
# Epoch 27/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0044 - mean_absolute_error: 0.0468
# Epoch 28/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0045 - mean_absolute_error: 0.0476
# Epoch 29/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0043 - mean_absolute_error: 0.0466
# Epoch 30/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0044 - mean_absolute_error: 0.0463
# Epoch 31/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0044 - mean_absolute_error: 0.0464
# Epoch 32/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0046 - mean_absolute_error: 0.0478
# Epoch 33/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0047 - mean_absolute_error: 0.0487
# Epoch 34/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0047 - mean_absolute_error: 0.0475
# Epoch 35/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0481
# Epoch 36/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0042 - mean_absolute_error: 0.0458
# Epoch 37/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0042 - mean_absolute_error: 0.0457
# Epoch 38/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mean_absolute_error: 0.0467
# Epoch 39/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0045 - mean_absolute_error: 0.0481
# Epoch 40/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0045 - mean_absolute_error: 0.0470
# Epoch 41/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0041 - mean_absolute_error: 0.0461
# Epoch 42/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0455
# Epoch 43/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mean_absolute_error: 0.0466
# Epoch 44/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mean_absolute_error: 0.0466
# Epoch 45/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mean_absolute_error: 0.0461
# Epoch 46/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mean_absolute_error: 0.0467
# Epoch 47/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0042 - mean_absolute_error: 0.0463
# Epoch 48/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0046 - mean_absolute_error: 0.0480
# Epoch 49/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0045 - mean_absolute_error: 0.0480
# Epoch 50/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0042 - mean_absolute_error: 0.0461
# Epoch 51/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0045 - mean_absolute_error: 0.0475
# Epoch 52/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mean_absolute_error: 0.0472
# Epoch 53/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0045 - mean_absolute_error: 0.0478
# Epoch 54/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0048 - mean_absolute_error: 0.0489
# Epoch 55/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0051 - mean_absolute_error: 0.0492
# Epoch 56/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0046 - mean_absolute_error: 0.0468
# Epoch 57/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0042 - mean_absolute_error: 0.0467
# Epoch 58/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mean_absolute_error: 0.0465
# Epoch 59/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0046 - mean_absolute_error: 0.0480
# Epoch 60/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0467
# Epoch 61/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0041 - mean_absolute_error: 0.0454
# Epoch 62/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - mean_absolute_error: 0.0452
# Epoch 63/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0045 - mean_absolute_error: 0.0473
# Epoch 64/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0467
# Epoch 65/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mean_absolute_error: 0.0465
# Epoch 66/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - mean_absolute_error: 0.0460
# Epoch 67/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0045 - mean_absolute_error: 0.0474
# Epoch 68/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mean_absolute_error: 0.0465
# Epoch 69/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0044 - mean_absolute_error: 0.0470
# Epoch 70/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0040 - mean_absolute_error: 0.0450
# Epoch 71/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0044 - mean_absolute_error: 0.0473
# Epoch 72/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - mean_absolute_error: 0.0472
# Epoch 73/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0046 - mean_absolute_error: 0.0465
# Epoch 74/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0046 - mean_absolute_error: 0.0479
# Epoch 75/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0043 - mean_absolute_error: 0.0469
# Epoch 76/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0042 - mean_absolute_error: 0.0463
# Epoch 77/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0046 - mean_absolute_error: 0.0474
# Epoch 78/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0045 - mean_absolute_error: 0.0478
# Epoch 79/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0047 - mean_absolute_error: 0.0481
# Epoch 80/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0046 - mean_absolute_error: 0.0484
# Epoch 81/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0049 - mean_absolute_error: 0.0489
# Epoch 82/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mean_absolute_error: 0.0468
# Epoch 83/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - mean_absolute_error: 0.0481
# Epoch 84/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0047 - mean_absolute_error: 0.0491
# Epoch 85/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0045 - mean_absolute_error: 0.0477
# Epoch 86/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0042 - mean_absolute_error: 0.0455
# Epoch 87/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - mean_absolute_error: 0.0458
# Epoch 88/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mean_absolute_error: 0.0462
# Epoch 89/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mean_absolute_error: 0.0471
# Epoch 90/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0045 - mean_absolute_error: 0.0475
# Epoch 91/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mean_absolute_error: 0.0464
# Epoch 92/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0046 - mean_absolute_error: 0.0477
# Epoch 93/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mean_absolute_error: 0.0462
# Epoch 94/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0046 - mean_absolute_error: 0.0484
# Epoch 95/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0046 - mean_absolute_error: 0.0477
# Epoch 96/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - mean_absolute_error: 0.0448
# Epoch 97/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0045 - mean_absolute_error: 0.0468
# Epoch 98/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0045 - mean_absolute_error: 0.0481
# Epoch 99/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - mean_absolute_error: 0.0460
# Epoch 100/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mean_absolute_error: 0.0475
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# Now let's print out what you have done :)

# %%
import math
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt


train_rmse = math.sqrt(mean_squared_error(y_train, train_predict))
test_rmse = math.sqrt(mean_squared_error(y_test, test_predict))
# Print RMSE
print('Train RMSE: %.3f RMSE' % (train_rmse))
print('Test RMSE: %.3f RMSE' % (test_rmse))

actual = np.append(y_train, y_test)
predictions = np.append(train_predict, test_predict)
rows = len(actual)
plt.figure(figsize=(15, 6), dpi=120)
plt.plot(range(rows), actual)
plt.plot(range(rows), predictions)
plt.axvline(x=len(y_train), color='r')
plt.legend(['Actual', 'Predictions'])
plt.xlabel('Observation number after given time steps')
plt.ylabel('Sunspots scaled')
plt.title('Actual and Predicted Values. The Red Line Separates The Training And Test Examples')
# Out:
# Train RMSE: 0.067 RMSE
# Test RMSE: 0.088 RMSE
# Text(0.5, 1.0, 'Actual and Predicted Values. The Red Line Separates The Training And Test Examples')
